# %% [markdown]
# # Actividad Final 5.16

# %% [markdown]
# Para los puntos marcadas indica los valores de presión, entalpía, temperatura, entropía y volumenn específico.

# %%
import pyromat as pm
pm.config["unit_pressure"] = "kPa"
pm.config["def_p"] = 100
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ![516.jpg](attachment:516.jpg)
